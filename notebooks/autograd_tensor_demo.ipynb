# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from autograd.tensor.engine import Tensor
from autograd.tensor.nn import MLP, CrossEntropyLoss

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
np.random.seed(47)
random.seed(47)

# %%
import numpy as np
import struct


def load_images(path):
    with open(path, "rb") as f:
        magic, num, rows, cols = struct.unpack(">IIII", f.read(16))
        images = np.frombuffer(f.read(), dtype=np.uint8)
        images = images.reshape(num, rows * cols)
        return images.astype(np.float32) / 255.0  # normalize


def load_labels(path):
    with open(path, "rb") as f:
        magic, num = struct.unpack(">II", f.read(8))
        labels = np.frombuffer(f.read(), dtype=np.uint8)
        return labels

# %%
X_train = load_images("../data/train-images.idx3-ubyte")
y_train = load_labels("../data/train-labels.idx1-ubyte")

X_test = load_images("../data/t10k-images.idx3-ubyte")
y_test = load_labels("../data/t10k-labels.idx1-ubyte")

print(X_train.shape)  # (60000, 784)
print(y_train.shape)  # (60000,)
# Out:
# (60000, 784)
# (60000,)

# %%
# Initialize a model 
model = MLP(784, [256, 256, 256, 10])
print(model)
print("Number of parameters", sum(p.data.size for p in model.parameters()))
# Out:
# Sequential(
#   (0): Linear(in=784, out=256)
#   (1): ReLU()
#   (2): Linear(in=256, out=256)
#   (3): ReLU()
#   (4): Linear(in=256, out=256)
#   (5): ReLU()
#   (6): Linear(in=256, out=10)
# )
# Number of parameters 335114

# %%
# Training loop (PyTorch-style)
batch_size = 256
num_epochs = 200
learning_rate = 0.1

criterion = CrossEntropyLoss()
train_losses = []
train_accs = []

for epoch in range(num_epochs):

    # Sample a batch
    if batch_size is None:
        Xb, yb = X_train, y_train
    else:
        ri = np.random.permutation(X_train.shape[0])[:batch_size]
        Xb, yb = X_train[ri], y_train[ri]

    # Convert batch to a single Tensor (batch_size, in_features)
    inputs = Tensor(Xb)

    # Forward pass — model outputs shape (batch_size, num_classes)
    logits = model(inputs)

    # Compute cross-entropy loss
    loss = criterion(logits, yb)

    # L2 regularization
    lambda_reg = 1e-4
    l2_reg = sum(
        (p * p).sum() for p in model.parameters()
    )
    total_loss = loss + lambda_reg * l2_reg

    # Compute accuracy (numpy, no grad needed)
    preds = np.argmax(logits.data, axis=1)
    acc = (preds == yb).mean()

    # Zero gradients
    model.zero_grad()

    # Backward pass
    total_loss.backward()

    # Update weights (SGD with linear LR decay)
    lr = learning_rate - 0.9 * learning_rate * epoch / num_epochs
    for p in model.parameters():
        p.data -= lr * p.grad

    # Record metrics
    train_losses.append(float(total_loss.data))
    train_accs.append(float(acc))

    # Log progress
    if epoch % 1 == 0:
        print(f"Epoch {epoch:3d} | Loss: {total_loss.data:.4f} | Accuracy: {acc*100:.2f}%")
# Out:
# Epoch   0 | Loss: 3.4932 | Accuracy: 9.38%
# Epoch   1 | Loss: 3.4089 | Accuracy: 13.67%
# Epoch   2 | Loss: 2.5889 | Accuracy: 25.39%
# Epoch   3 | Loss: 2.3071 | Accuracy: 33.98%
# Epoch   4 | Loss: 2.0380 | Accuracy: 41.41%
# Epoch   5 | Loss: 1.8675 | Accuracy: 53.52%
# Epoch   6 | Loss: 1.6317 | Accuracy: 65.62%
# Epoch   7 | Loss: 1.5484 | Accuracy: 66.02%
# Epoch   8 | Loss: 1.5379 | Accuracy: 62.89%
# Epoch   9 | Loss: 1.3925 | Accuracy: 70.70%
# Epoch 114 | Loss: 0.5751 | Accuracy: 92.58%
# Epoch 115 | Loss: 0.6933 | Accuracy: 87.11%
# Epoch 116 | Loss: 0.6326 | Accuracy: 88.67%
# Epoch 117 | Loss: 0.7358 | Accuracy: 91.80%
# Epoch 118 | Loss: 0.6493 | Accuracy: 90.62%
# Epoch 119 | Loss: 0.6103 | Accuracy: 91.80%
# Epoch 120 | Loss: 0.6497 | Accuracy: 90.62%
# Epoch 121 | Loss: 0.6025 | Accuracy: 92.19%
# Epoch 122 | Loss: 0.5791 | Accuracy: 94.14%
# Epoch 123 | Loss: 0.6438 | Accuracy: 90.62%
# Epoch 124 | Loss: 0.6820 | Accuracy: 89.45%
# Epoch 125 | Loss: 0.7284 | Accuracy: 89.84%
# Epoch 126 | Loss: 0.6862 | Accuracy: 89.84%
# Epoch 127 | Loss: 0.6272 | Accuracy: 92.19%
# Epoch 128 | Loss: 0.6802 | Accuracy: 90.23%
# Epoch 129 | Loss: 0.7032 | Accuracy: 87.89%
# Epoch 130 | Loss: 0.5336 | Accuracy: 93.36%
# Epoch 131 | Loss: 0.5444 | Accuracy: 93.36%
# Epoch 132 | Loss: 0.6844 | Accuracy: 88.67%
# Epoch 133 | Loss: 0.6354 | Accuracy: 90.23%
# Epoch 134 | Loss: 0.5963 | Accuracy: 92.97%
# Epoch 135 | Loss: 0.5896 | Accuracy: 93.75%
# Epoch 136 | Loss: 0.6362 | Accuracy: 90.23%
# Epoch 137 | Loss: 0.6031 | Accuracy: 91.02%
# Epoch 138 | Loss: 0.6877 | Accuracy: 90.62%
# Epoch 139 | Loss: 0.7012 | Accuracy: 89.45%
# Epoch 140 | Loss: 0.6545 | Accuracy: 92.19%
# Epoch 141 | Loss: 0.6534 | Accuracy: 91.02%
# Epoch 142 | Loss: 0.6925 | Accuracy: 89.45%
# Epoch 143 | Loss: 0.6854 | Accuracy: 90.23%
# Epoch 144 | Loss: 0.7372 | Accuracy: 86.72%
# Epoch 145 | Loss: 0.6126 | Accuracy: 93.36%
# Epoch 146 | Loss: 0.7204 | Accuracy: 89.84%
# Epoch 147 | Loss: 0.6344 | Accuracy: 92.19%
# Epoch 148 | Loss: 0.6555 | Accuracy: 90.62%
# Epoch 149 | Loss: 0.6280 | Accuracy: 91.80%
# Epoch 150 | Loss: 0.6654 | Accuracy: 90.62%
# Epoch 151 | Loss: 0.6172 | Accuracy: 91.41%
# Epoch 152 | Loss: 0.6214 | Accuracy: 91.80%
# Epoch 153 | Loss: 0.6340 | Accuracy: 92.19%
# Epoch 154 | Loss: 0.6093 | Accuracy: 91.80%
# Epoch 155 | Loss: 0.6206 | Accuracy: 92.19%
# Epoch 156 | Loss: 0.6893 | Accuracy: 89.84%
# Epoch 157 | Loss: 0.6727 | Accuracy: 92.58%
# Epoch 158 | Loss: 0.7566 | Accuracy: 89.06%
# Epoch 159 | Loss: 0.6245 | Accuracy: 91.02%
# Epoch 160 | Loss: 0.6285 | Accuracy: 91.80%
# Epoch 161 | Loss: 0.6832 | Accuracy: 88.67%
# Epoch 162 | Loss: 0.6081 | Accuracy: 90.23%
# Epoch 163 | Loss: 0.6103 | Accuracy: 91.02%
# Epoch 164 | Loss: 0.6558 | Accuracy: 89.45%
# Epoch 165 | Loss: 0.6791 | Accuracy: 91.80%
# Epoch 166 | Loss: 0.6075 | Accuracy: 92.97%
# Epoch 167 | Loss: 0.6172 | Accuracy: 92.19%
# Epoch 168 | Loss: 0.5518 | Accuracy: 93.75%
# Epoch 169 | Loss: 0.5571 | Accuracy: 92.97%
# Epoch 170 | Loss: 0.5757 | Accuracy: 94.53%
# Epoch 171 | Loss: 0.5608 | Accuracy: 93.75%
# Epoch 172 | Loss: 0.6115 | Accuracy: 91.41%
# Epoch 173 | Loss: 0.6169 | Accuracy: 91.80%
# Epoch 174 | Loss: 0.6952 | Accuracy: 91.02%
# Epoch 175 | Loss: 0.6200 | Accuracy: 90.62%
# Epoch 176 | Loss: 0.6033 | Accuracy: 91.02%
# Epoch 177 | Loss: 0.6043 | Accuracy: 91.41%
# Epoch 178 | Loss: 0.6265 | Accuracy: 90.62%
# Epoch 179 | Loss: 0.6874 | Accuracy: 89.45%
# Epoch 180 | Loss: 0.6455 | Accuracy: 92.58%
# Epoch 181 | Loss: 0.6084 | Accuracy: 91.80%
# Epoch 182 | Loss: 0.5551 | Accuracy: 93.75%
# Epoch 183 | Loss: 0.5819 | Accuracy: 93.36%
# Epoch 184 | Loss: 0.7228 | Accuracy: 90.23%
# Epoch 185 | Loss: 0.6184 | Accuracy: 89.84%
# Epoch 186 | Loss: 0.6105 | Accuracy: 88.67%
# Epoch 187 | Loss: 0.6193 | Accuracy: 89.84%
# Epoch 188 | Loss: 0.6192 | Accuracy: 92.97%
# Epoch 189 | Loss: 0.5819 | Accuracy: 92.97%
# Epoch 190 | Loss: 0.6478 | Accuracy: 90.23%
# Epoch 191 | Loss: 0.6331 | Accuracy: 91.41%
# Epoch 192 | Loss: 0.6674 | Accuracy: 90.62%
# Epoch 193 | Loss: 0.6149 | Accuracy: 90.62%
# Epoch 194 | Loss: 0.5702 | Accuracy: 94.53%
# Epoch 195 | Loss: 0.7099 | Accuracy: 89.45%
# Epoch 196 | Loss: 0.5876 | Accuracy: 92.97%
# Epoch 197 | Loss: 0.6680 | Accuracy: 92.19%
# Epoch 198 | Loss: 0.5724 | Accuracy: 94.53%
# Epoch 199 | Loss: 0.6364 | Accuracy: 91.02%

# %%
# Plot training loss and accuracy
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.plot(train_losses)
ax1.set_title("Training Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Cross-Entropy Loss")

ax2.plot([a * 100 for a in train_accs])
ax2.set_title("Training Accuracy")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Accuracy (%)")

plt.tight_layout()
plt.savefig("../images/tensor_loss_curves.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# Evaluate on test set
test_inputs = Tensor(X_test, requires_grad=False)
test_logits = model(test_inputs)
test_preds = np.argmax(test_logits.data, axis=1)
test_acc = (test_preds == y_test).mean()
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Show a few predictions
fig, axes = plt.subplots(2, 5, figsize=(14, 5))
for i, ax in enumerate(axes.flat):
    ax.imshow(X_test[i].reshape(28, 28), cmap='gray')
    color = 'green' if test_preds[i] == y_test[i] else 'red'
    ax.set_title(f"P:{test_preds[i]}\nT:{y_test[i]}", fontsize=7, color=color)
    ax.axis('off')
plt.suptitle("Test Predictions (green=correct, red=wrong)", y=1.02)
plt.tight_layout()
plt.savefig("../images/MNIST_predictions.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Test Accuracy: 92.02%
